# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshvardhan-To1/01/blob/main/ENOSIUM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SECRET_KEY = "AIzaSyAU_9QPsdQI6Fx0eqP3_PIKREMS1tWxLog"

# %%
Request1 = input("Enter which grade you are in :")
Request2 = input("Enter which subject you like to know guide to :")
Request3 = input("Enter which field you are weak in :")
Request4 = input("Enter what is your level in the subject in a scale of 10:")
# Out:
# Enter which grade you are in :12
# Enter which subject you like to know guide to :CHmeistry
# Enter which field you are weak in :nothing
# Enter what is your level in the subject in a scale of 10:9

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai

genai.configure(api_key=SECRET_KEY)

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

convo = model.start_chat(history=[
])

convo.send_message(f'Suggest some good study material for a student studying in{Request1} for the subject of {Request2} and the level of student int he subject in a range of 1-10 is {Request4} and also the student is weak in {Request3}, also provide URL for whichever possible')
print(convo.last.text)
# Out:
# 1. NCERT Chemistry Textbooks (Class 11 and 12):
#  - https://ncert.nic.in/ncerts/l/ke123.pdf
#  - https://ncert.nic.in/ncerts/l/ke124.pdf
#
# 2. Chemistry Reference Books:
#  - Modern's ABC of Chemistry for Classes 11 and 12 by S.P. Jauhar: https://www.amazon.in/Moderns-ABC-Chemistry-Class-Reference/dp/8172334817
#  - Concise Inorganic Chemistry by J.D. Lee: https://www.amazon.in/Concise-Inorganic-Chemistry-J-Lee/dp/8126514977
#  - Organic Chemistry by Morrison and Boyd: https://www.amazon.in/Organic-Chemistry-Robert-Thornton-Morrison/dp/0132397953
#  - Physical Chemistry by P.W. Atkins and Julio de Paula: https://www.amazon.in/Physical-Chemistry-Atkins-de-Paula/dp/1118443793
#
# 3. Chemistry Study Guides:
#  - Chemistry: The Central Science by Theodore L. Brown, H. Eugene LeMay, Jr., Bruce E. Bursten, and Catherine J. Murphy (International Edition): https://www.amazon.in/Chemistry-Central-Theodore-Brown-International/dp/1118931249
# ...

# %%
! pip install transformers datasets -q
! pip install transformers datasets evaluate rouge_score -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 716.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization", model="stevhliu/my_awesome_billsum_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
# !pip install PyPDF2
# !pip install pymupdf Pillow
# !pip install --upgrade pymupdf
# !pip install fitz[all] Pillow
# !pip install fitz
import os
import pytesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 23.0 MB/s eta 0:00:00
# ...
# WARNING: fitz 0.0.1.dev2 does not provide the extra 'all'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 33.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 52.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.5 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# ...

# %%
from PyPDF2 import PdfReader

# %%
def summarize(path):
  reader = PdfReader(path)
  strk = ""
  for i in range(len(reader.pages)):
    k = reader.pages[i].extract_text()
    strk = summarizer(k)[0]['summary_text'] + strk
  return strk

# %%
from PyPDF2 import PdfReader
path = "/content/Chemistry.pdf"
qp = PdfReader(path)
topics = ""
for i in range(len(qp.pages)):
    details = qp.pages[i].extract_text()
    topics = topics + details
convo.send_message(f"can you please summarize from what all topics the questions have been asked in this question paper for {Request1} std (exclude name of subject):\n" + topics)
syl = convo.last.text
print(syl)
# Out:
# The following topics have been covered in the question paper:
#
# 1. Chemical Bonding
# 2. Solid State
# 3. Solutions
# 4. Chemical Kinetics
# 5. Electrochemistry
# 6. Coordination Compounds
# 7. Organic Chemistry
#     * Haloalkanes and Haloarenes
#     * Alcohols, Phenols and Ethers
#     * Aldehydes, Ketones and Carboxylic Acids
#     * Amines
#     * Biomolecules
# 8. Polymers
# 9. Chemistry in Everyday Life
# 10. Surface Chemistry

# %%
convo.send_message(f"Create a question paper of {100} marks for a student in {Request1} std, with marking scheme used and answer key in the end:\n, on syllabus " + syl)
question_paper = convo.last.text
print(question_paper)
# Out:
# **Question Paper**
#
# **Class 12 Chemistry**
#
# **Total Marks: 100**
#
# **Time: 3 Hours**
#
# **Instructions:**
#
# * All questions are compulsory.
# * The marks for each question are indicated against it.
# * Write your answers neatly and legibly.
#
# **Section A**
#
# **Multiple Choice Questions (1 mark each)**
#
# 1. Which of the following is an example of a covalent bond?
#     (a) NaCl
#     (b) H2O
#     (c) CaO
#     (d) CO2
#
# 2. Which of the following is a network solid?
#     (a) Graphite
#     (b) Diamond
#     (c) Sodium chloride
#     (d) Ice
#
# 3. Which of the following solutions has the highest boiling point?
#     (a) 1 M NaCl solution
#     (b) 1 M glucose solution
#     (c) 1 M urea solution
#     (d) Pure water
#
# 4. The rate of a chemical reaction can be increased by:
#     (a) Increasing the temperature
#     (b) Increasing the concentration of the reactants
#     (c) Adding a catalyst
#     (d) All of the above
#
# ...

# %%
# !pip install fpdf
from fpdf import FPDF

# %%
import textwrap
def text_to_pdf(text, filename):
    a4_width_mm = 210
    pt_to_mm = 0.35
    fontsize_pt = 10
    fontsize_mm = fontsize_pt * pt_to_mm
    margin_bottom_mm = 10
    character_width_mm = 7 * pt_to_mm
    width_text = a4_width_mm / character_width_mm

    pdf = FPDF(orientation='P', unit='mm', format='A4')
    pdf.set_auto_page_break(True, margin=margin_bottom_mm)
    pdf.add_page()
    pdf.set_font(family='Courier', size=fontsize_pt)
    splitted = text.split('\n')

    for line in splitted:
        lines = textwrap.wrap(line, width_text)

        if len(lines) == 0:
            pdf.ln()

        for wrap in lines:
            pdf.cell(0, fontsize_mm, wrap, ln=1)

    pdf.output(filename, 'F')

# %%
text_to_pdf(question_paper,"questionpp")
